# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd
import re

def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
xl = pd.read_csv('leader.csv')

# %%
xl
# Out:
#                                     Name  \
# 0                            HANNAH YEOH
# 1                NIK NAZMI BIN NIK AHMAD
# 2                        RINA MOHD HARUN
# 3                    SHAHIDAN BIN KASSIM
# 4     DATO' DR. HAJI ABD RAHMAN BIN DAUD
# 5                     USTAZ HASHIM JASIN
# 6                DR MAHATHIR BIN MOHAMAD
# 7             DATO' IR. NAWAWI BIN AHMAD
# 8                       MUKHRIZ MAHATHIR
# 9                   ABD. GHANI BIN AHMAD
# 10                       OTHMAN BIN AZIZ
# 11                NORHAFIZA BINTI FADZIL
# 12             DATO' SERI MAHDZIR KHALID
# 13                  DATO' HJ MAHFUZ OMAR
# 14                         CHAN MING KAI
# 15                       DR AZMAN ISMAIL
# 16                    WAN SAIFUL WAN JAN
# 17           AKHRAMSYAH BIN SANUSI JUNID
# 18         DATO' TAJUL URUS HJ. MAT ZAIN
# 19                    DATO' JOHARI ABDUL
# 20   DATO' SHAHANIM BINTI MOHAMAD YUSOFF
# 21                     DATUK AZEEZ RAHIM
# 22       DATO' SAIFUDDIN NASUTION ISMAIL
# 23              DATO HJ CHE LAH MAT NAWI
# 24                             DATUK WAN
# 25                   USTAZ MARZUK SHAARY
# 26                            HUSAM MUSA
# 27                        FIKHRAN HAMSHI
# 28                   USTAZ FADHLI SHAARI
# 29                    USTAZ TUAN IBRAHIM
# ..                                   ...
# 124                            WONG CHEN
# 125                    IR. TAN SEONG LIM
# 126                         SHAHIR ADNAN
# 127                          TOH SIN WAH
# 128                  MARIA CHIN ABDULLAH
# 129                             TONY PUA
# 130                      SIVARASA RASIAH
# 131                       A. PRAKASH RAO
# 132                     KHALID ABD SAMAD
# 133                   HAJI AZHARI SHAARI
# 134            DR MOHD ZUHDI BIN MARSUKI
# 135                      MOHANA MUNIANDY
# 136                     CHARLES SANTIAGO
# 137                         MOHAMAD SABU
# 138                           V. GUNALAN
# 139                  DR XAVIER JAYAKUMAR
# 140                       SHAHRIL HAMDAN
# 141                 DATUK DR. YAHYA BABA
# 142          DATO' HAJI MARSUM BIN PAING
# 143                      SABIRIN MARSONO
# 144                          LIM LIP ENG
# 145             DR. DOMINIC LAU HOE CHAI
# 146                      DR. TAN YEE KEW
# 147                          HANNAH YEOH
# 148                      LOGA BALA MOHAN
# 149                         SOLLEH RAZAK
# 150              NIK NAZMI BIN NIK AHMAD
# 151        USTAZ UBAID BIN HAJI ABD AKLA
# 152                      RINA MOHD HARUN
# 153              DATUK SERI JOHARI GHANI
#
#                                               Facebook  \
# 0                 https://www.facebook.com/hannahyeoh/
# 1           https://www.facebook.com/niknazminikahmad/
# 2          https://www.facebook.com/rinaharunsrikandi/
# 3                     https://www.facebook.com/ybdssk/
# 4    https://www.facebook.com/CikguRahman.PakatanHa...
# 5            https://www.facebook.com/hashimjasinakil/
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# ..                                           ...
# 124                                          NaN
# 125                                          NaN
# 126                                          NaN
# 127                                          NaN
# 128                                          NaN
# 129                                          NaN
# 130                                          NaN
# 131                                          NaN
# 132                                          NaN
# 133                                          NaN
# 134                                          NaN
# 135                                          NaN
# 136                                          NaN
# 137                                          NaN
# 138                                          NaN
# 139                                          NaN
# 140                                          NaN
# 141                                          NaN
# 142                                          NaN
# 143                                          NaN
# 144                                          NaN
# 145                                          NaN
# 146                                          NaN
# 147                                          NaN
# 148                                          NaN
# 149                                          NaN
# 150                                          NaN
# 151                                          NaN
# 152                                          NaN
# 153                                          NaN
#
# [154 rows x 4 columns]

# %%
len(xl.index)
# Out:
# 154

# %%
def ObtainFb(xl):
    """
    Obtain the name of the leader and his/her facebook follower count
    """
    FollowerDf = pd.DataFrame()
    for i in list(range(0,len(xl.index))): 
        raw_html = simple_get(xl.iloc[i,1])
        if raw_html == None:
            numberOfFollowers = None
        else:
            html = BeautifulSoup(raw_html, 'html.parser')
            listOfTab = [item['data-key'] for item in html.find_all('div', attrs={'data-key' : True})]

            tab = html.find('div',attrs = {'data-key' : 'tab_community'})
            if tab == None:
                numberOfFollowers = None
            else:
                nextURL = tab.a["href"]
                nextURL = "https://www.facebook.com/" + nextURL

                next_raw_html = simple_get(nextURL)
                next_html = BeautifulSoup(next_raw_html, 'html.parser')

                numberOfFollowers = next_html.select("div._3xom")[1].text

                temp = pd.DataFrame({'name':xl.iloc[i,0], 'FB':numberOfFollowers}, index=[i])
                FollowerDf = FollowerDf.append(temp)
    return FollowerDf
    

def ObtainTwit(xl):
    """
    Obtain the Twitter follower and post counts from Social Blade 
    """
    FollowerDf1 = pd.DataFrame()
    for i in list(range(0,len(xl.index))): 
            raw_html = xl.iloc[i,2]
            if raw_html == None:
                numberOfFollowers = None
            else:
                regex1 = re.compile(r"(com/)([a-zA-Z]+)")
                match = regex1.search(raw_html)
                #For twitter
                socialBladeURL = "https://socialblade.com/twitter/user/"+match[2]+"/monthly"

                raw_html2 = simple_get(socialBladeURL)
                html = BeautifulSoup(raw_html2, 'html.parser')
                k =html.find_all("script", attrs = {"type":"text/javascript"})
                
                
                
                regex2 = re.compile(r"(2018-05-08,)(\d+)")
                
                #Follower count
                match1 = regex2.search(k[6].text)
                if match1 is not None:
                    numberOfFollowers1 = match1[2]
                else:
                    numberOfFollowers1 = None
                    
                #Tweet count
                match2 = regex2.search(k[10].text)
                if match2 is not None:
                    numberOfFollowers2 = match2[2]
                else:
                    numberOfFollowers2 = None
            temp = pd.DataFrame({'TWFollower':numberOfFollowers1, "TWTweet":numberOfFollowers2}, index=[i])
            FollowerDf1 = FollowerDf1.append(temp)
            
    return FollowerDf1

def joinColumns(*dataframes):
    return pd.concat(dataframes,1)

# %%
ObtainFb(xl)
# Out:
#                                     name      FB
# 0                            HANNAH YEOH    295K
# 1                NIK NAZMI BIN NIK AHMAD    113K
# 2                        RINA MOHD HARUN   9,101
# 3                    SHAHIDAN BIN KASSIM   8,545
# 4     DATO' DR. HAJI ABD RAHMAN BIN DAUD     750
# 5                     USTAZ HASHIM JASIN  22,536
# 6                DR MAHATHIR BIN MOHAMAD    3.5J
# 7             DATO' IR. NAWAWI BIN AHMAD     676
# 8                       MUKHRIZ MAHATHIR    515K
# 9                   ABD. GHANI BIN AHMAD   2,153
# 10                       OTHMAN BIN AZIZ   2,961
# 11                NORHAFIZA BINTI FADZIL    387K
# 12             DATO' SERI MAHDZIR KHALID    103K
# 13                  DATO' HJ MAHFUZ OMAR  31,426
# 14                         CHAN MING KAI  15,056
# 15                       DR AZMAN ISMAIL   4,498
# 16                    WAN SAIFUL WAN JAN  13,786
# 17           AKHRAMSYAH BIN SANUSI JUNID   2,615
# 18         DATO' TAJUL URUS HJ. MAT ZAIN   2,097
# 19                    DATO' JOHARI ABDUL   3,281
# 20   DATO' SHAHANIM BINTI MOHAMAD YUSOFF  10,951
# 21                     DATUK AZEEZ RAHIM  12,337
# 22       DATO' SAIFUDDIN NASUTION ISMAIL  28,209
# 23              DATO HJ CHE LAH MAT NAWI   8,035
# 24                             DATUK WAN   3,560
# 25                   USTAZ MARZUK SHAARY   5,365
# 26                            HUSAM MUSA  97,835
# 27                        FIKHRAN HAMSHI   5,215
# 28                   USTAZ FADHLI SHAARI  19,138
# 29                    USTAZ TUAN IBRAHIM    221K
# ..                                   ...     ...
# 123                     GOBIND SINGH DEO  27,166
# 124                            WONG CHEN  55,350
# 125                    IR. TAN SEONG LIM   3,244
# 126                         SHAHIR ADNAN   1,966
# 127                          TOH SIN WAH     220
# 128                  MARIA CHIN ABDULLAH   6,113
# 129                             TONY PUA    351K
# 130                      SIVARASA RASIAH  36,718
# 131                       A. PRAKASH RAO   6,843
# 132                     KHALID ABD SAMAD  35,487
# 133                   HAJI AZHARI SHAARI   7,998
# 134            DR MOHD ZUHDI BIN MARSUKI   7,914
# 135                      MOHANA MUNIANDY   3,175
# 136                     CHARLES SANTIAGO  49,550
# 137                         MOHAMAD SABU    238K
# 138                           V. GUNALAN   2,532
# 139                  DR XAVIER JAYAKUMAR  43,653
# 140                       SHAHRIL HAMDAN  26,729
# 142          DATO' HAJI MARSUM BIN PAING   2,312
# 143                      SABIRIN MARSONO   1,789
# 144                          LIM LIP ENG  42,650
# 145             DR. DOMINIC LAU HOE CHAI  12,311
# 146                      DR. TAN YEE KEW   1,592
# 147                          HANNAH YEOH    295K
# 148                      LOGA BALA MOHAN      51
# 149                         SOLLEH RAZAK   2,533
# 150              NIK NAZMI BIN NIK AHMAD    113K
# 151        USTAZ UBAID BIN HAJI ABD AKLA   1,454
# 152                      RINA MOHD HARUN   9,101
# 153              DATUK SERI JOHARI GHANI  46,586
#
# [148 rows x 2 columns]

# %%
ObtainTwit(xl)
# Out:
#     TWFollower TWTweet
# 0       180908   20065
# 1        81456   37129
# 2         None    None
# 3         None    None
# 4          222       0
# 5         None    None
# 6       457407    1513
# 7         None    None
# 8         None    None
# 9         None    None
# 10        2635   75906
# 11        None    None
# 12        None    None
# 13        None    None
# 14        None    None
# 15        None    None
# 16       14591    9125
# 17        1737    7519
# 18        None    None
# 19        None    None
# 20        None    None
# 21        None    None
# 22        None    None
# 23      286425   10532
# 24        None    None
# 25        None    None
# 26        None    None
# 27        None    None
# 28        None    None
# 29        None    None
# ..         ...     ...
# 124       None    None
# 125       None    None
# 126       None    None
# 127      15339    9716
# 128       7011    6236
# 129     216310    9809
# 130       None    None
# 131       None    None
# 132       None    None
# 133       None    None
# 134       None    None
# 135       None    None
# 136      24875   22265
# 137       None    None
# 138       None    None
# 139       None    None
# 140       7434   15793
# 141      13018    9245
# 142       None    None
# 143       None    None
# 144      14905   11560
# 145       None    None
# 146       None    None
# 147     180908   20065
# 148       None    None
# 149        232     169
# 150      81456   37129
# 151       None    None
# 152       None    None
# 153       None    None
#
# [154 rows x 2 columns]

# %%
raw_html = "https://twitter.com/guanenglim"
if raw_html == None:
    numberOfFollowers = None
else:
    regex1 = re.compile(r"(com/)([a-zA-Z]+)")
    match = regex1.search(raw_html)
    #For twitter
    socialBladeURL = "https://socialblade.com/twitter/user/"+match[2]+"/monthly"

    raw_html2 = simple_get(socialBladeURL)
    html = BeautifulSoup(raw_html2, 'html.parser')
    k =html.find_all("script", attrs = {"type":"text/javascript"})

# %%
k[10]
# Out:
# <script type="text/javascript">
# 		g = new Dygraph(
#
# 		// containing div
# 		document.getElementById('TotalTweetsGained'),
# 		// CSV or path to a CSV file.
# 			"Date,Total Tweets\n" + "2018-05-12,15907\n" +"2018-05-13,15912\n" +"2018-05-14,15916\n" +"2018-05-15,15916\n" +"2018-05-16,15916\n" +"2018-05-17,15916\n" +"2018-05-18,15919\n" +"2018-05-19,15926\n" +"2018-05-20,15929\n" +"2018-05-21,15930\n" +"2018-05-22,15932\n" +"2018-05-23,15932\n" +"2018-05-24,15932\n" +"2018-05-25,15934\n" +"2018-05-26,15936\n" +"2018-05-27,15937\n" +"2018-05-28,15938\n" +"2018-05-29,15938\n" +"2018-05-30,15938\n" +"2018-05-31,15938\n" +"2018-06-01,15939\n" +"2018-06-02,15941\n" +"2018-06-03,15943\n" +"2018-06-04,15943\n" +"2018-06-05,15943\n" +"2018-06-06,15943\n" +"2018-06-07,15943\n" +"2018-06-08,15946\n" +"2018-06-09,15946\n" +"2018-06-10,15947\n" +"2018-06-11,15948\n" +"2018-06-12,15953\n" +"2018-06-13,15956\n" +"2018-06-14,15958\n" +"2018-06-15,15958\n" +"2018-06-16,15958\n" +"2018-06-17,15958\n" +"2018-06-18,15958\n" +"2018-06-19,15958\n" +"2018-06-20,15958\n" +"2018-06-21,15958\n" +"2018-06-22,15958\n" +"2018-06-23,15960\n" +"2018-06-24,15963\n" +"2018-06-25,15967\n" +"2018-06-26,15967\n" +"2018-06-27,15967\n" +"2018-06-28,15967\n" +"2018-06-29,15968\n" +"2018-06-30,15969\n" +"2018-07-01,15971\n" +"2018-07-02,15971\n" +"2018-07-03,15971\n" +"2018-07-04,15971\n" +"2018-07-05,15971\n" +"2018-07-06,15973\n" +"2018-07-07,15972\n" +"2018-07-08,15972\n" +"2018-07-09,15972\n" +"2018-07-10,15972\n" +"2018-07-11,15972\n" +"2018-07-12,15974\n" +"2018-07-13,15974\n" , {
# 				title: 'Total Tweets Posted for guanenglim',
# 				legend: 'always',
# 				ylabel: false,
# 				titleHeight: 20,
# 				labelsDivStyles: { 'background': 'none', 'margin-top': '-10px', 'text-align': 'right', },
# 				strokeWidth: 1,
# 				colors: ["#dd2323", "#dd2323", "#dd2323", "#dd2323"],
# 				labelsKMB: true,
# 				maxNumberWidth: 10
# 			}
# 		);
# 		</script>

# %%
raw_html = simple_get(socialBladeURL1)
html = BeautifulSoup(raw_html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-793bd9ad5250> in <module>()
#       1 raw_html = simple_get(socialBladeURL1)
# ----> 2 html = BeautifulSoup(raw_html, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     190         if hasattr(markup, 'read'):        # It's a file-type object.
#     191             markup = markup.read()
# --> 192         elif len(markup) <= 256 and (
#     193                 (isinstance(markup, bytes) and not b'<' in markup)
#     194                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'NoneType' has no len()

# %%
k[10]
# Out:
# <script type="text/javascript">
# 		g = new Dygraph(
#
# 		// containing div
# 		document.getElementById('TotalTweetsGained'),
# 		// CSV or path to a CSV file.
# 			"Date,Total Tweets\n" + "2018-07-12,629\n" , {
# 				title: 'Total Tweets Posted for RinaMohdHarun',
# 				legend: 'always',
# 				ylabel: false,
# 				titleHeight: 20,
# 				labelsDivStyles: { 'background': 'none', 'margin-top': '-10px', 'text-align': 'right', },
# 				strokeWidth: 1,
# 				colors: ["#dd2323", "#dd2323", "#dd2323", "#dd2323"],
# 				labelsKMB: true,
# 				maxNumberWidth: 10
# 			}
# 		);
# 		</script>

# %%
import re
#First assume that the twitter accounts exist for the users
for i in list(range(0,len(xl.index))):
# Out:
# HANNAH YEOH
# 2
# 180908
# NIK NAZMI BIN NIK AHMAD
# 2
# 81456

# %%
raw_html = xl.iloc[1,2]

# %%
socialBladeURL
# Out:
# 'https://socialblade.com/instagram/user/hannahyeoh/monthly'

# %%
raw_html = simple_get(socialBladeURL1)
html = BeautifulSoup(raw_html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-793bd9ad5250> in <module>()
#       1 raw_html = simple_get(socialBladeURL1)
# ----> 2 html = BeautifulSoup(raw_html, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     190         if hasattr(markup, 'read'):        # It's a file-type object.
#     191             markup = markup.read()
# --> 192         elif len(markup) <= 256 and (
#     193                 (isinstance(markup, bytes) and not b'<' in markup)
#     194                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'NoneType' has no len()

# %%
k[6].text
regex2 = re.compile(r"(2018-05-08,)(\d+)")
match1 = regex2.search(k[6].text)
numberOfFollowers = match1[2]

# %%
numberOfFollowers
# Out:
# '81456'
